# %%
import glob
import pandas as pd

# %% [markdown]
# # Load data

# %%
def load_evidence(fn):
    ds_name = fn.split("/")[-3]
    df = pd.read_json(fn)
    # Unwrap the 'source' column (contains a dictionary) into separate columns
    source_df = df['source'].apply(pd.Series)
    extracted_df = df['extracted'].apply(pd.Series).add_prefix('extracted_')
    # derived_df = df['derived'].apply(pd.Series).add_prefix('derived_')
    # Combine the original DataFrame with the unwrapped columns
    # df = pd.concat([df.drop(columns=['source', 'extracted', 'derived']), source_df, extracted_df, derived_df], axis=1)
    df = pd.concat([df.drop(columns=['source', 'extracted']), source_df, extracted_df], axis=1)
    df["ds"] = ds_name
    del df["derived"]
    return df

# %%
fns = glob.glob("../../data/*/evidence_human/evidence.json")

# %%
dfs = []
for fn in fns:
    dfs.append(load_evidence(fn))
df = pd.concat(dfs)

# %% [markdown]
# # Perform token alignment

# %%
tdeg = df.query("source_type == 'text'").copy()

# %%
tdeg.head(2)
# Out:
#   source_type                                   source_rationale source_id  \
# 0        text  Monocyte 1 strongly expressed FCGR3A (CD16) an...      text
# 1        text  Interestingly, ABCA1, which mediates sterol ef...      text
#
#   extracted_organism extracted_cell_type_label extracted_cell_source  \
# 0       homo_sapiens                Monocyte 1                kidney
# 1       homo_sapiens                Monocyte 1                kidney
#
#   extracted_cell_state extracted_feature_name extracted_feature_type  \
# 0                 none                 FCGR3A                   gene
# 1                 none                  ABCA1                   gene
#
#               ds
# 0  kidney_Wu2018
# 1  kidney_Wu2018

# %%
from extract.extract import align, norm_text

# %%
tdeg["source_cell_type_label"] = tdeg.apply(
    lambda x: align(norm_text(x["source_rationale"]), norm_text(x["extracted_cell_type_label"]))[0], 
    axis=1)
tdeg["source_feature_name"]    = tdeg.apply(
    lambda x: align(norm_text(x["source_rationale"]), norm_text(x["extracted_feature_name"]))[0], 
    axis=1)
# Out:
# /Users/nithya/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
tdeg["found_feature_name"] = tdeg["source_feature_name"] == tdeg["extracted_feature_name"]
tdeg["found_cell_type_label"] = tdeg["source_cell_type_label"] == tdeg["extracted_cell_type_label"]

# %%
nobs = tdeg.shape[0]
found_ct = tdeg["found_cell_type_label"].sum()
found_fn = tdeg["found_feature_name"].sum()
frac_ct = found_ct / nobs * 100
frac_fn = found_fn / nobs * 100

# %%
print(f"Features   found: {found_fn}/{nobs} ({frac_fn:.1f}%)")
print(f"Cell types found: {found_ct}/{nobs} ({frac_ct:.1f}%)")
# Out:
# Features   found: 185/1066 (17.4%)
# Cell types found: 114/1066 (10.7%)

# %% [markdown]
# ## Bigram Model

# %%
def sequence(target_tokens: list, source_tokens: list, target_index: int, source_index: int):
    """
    Given a list of target tokens and a list of source tokens, link the target tokens together while they match the source tokens
    """
    found_words = []
    
    if target_index >= len(target_tokens) or source_index >= len(source_tokens):
        return found_words, target_index + 1, source_index + 1
    elif target_tokens[target_index] == source_tokens[source_index]:
        found_words.append(target_tokens[target_index])
        (found_word, target_index, source_index) = sequence(target_tokens[target_index + 1:], source_tokens[source_index+1:], target_index + 1, source_index + 1)
        found_words.append(found_word)
        return found_words, target_index, source_index
    else:
        return found_words, target_index + 1, source_index + 1

# %%
def find_matching_segments(target_tokens: list, source_tokens: list):
    result = []
    target_index, source_index = 0,0
    
    while target_index < len(target_tokens) and source_index < len(source_tokens):
        (found_segment, target_index, source_index) = sequence(target_tokens, source_tokens, target_index, source_index)
        result.append(found_segment)

    return result

# %%
#find_matching_segments(tdeg["extracted_feature_name"].to_list(), tdeg["source_feature_name"].to_list())

tdeg["source_feature_name"]
# Out:
# 0       GR3A
# 1          1
# 2       SDC3
# 3          E
# 4      PDE3A
#        ...
# 97      PTL1
# 98      PTL2
# 99      PTL4
# 100       GF
# 101       N1
# Name: source_feature_name, Length: 1066, dtype: object
